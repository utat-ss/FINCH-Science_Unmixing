# %%
import general_functions

# %%
general_functions.run_dirichlet_model("simpler_data.csv", wsig=2, bsig=2)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 4168 seconds.
# ----- Convergence diagnostics -----
# w shape: (80, 3, 4000), b shape: (3, 4000)
# linear shape: (4000, 345, 3), any nan: False, any inf: False
# alpha shape: (4000, 345, 3), min: 0.0009, max: 23.4569
#
# ----- Prediction results using the mean of the predictions -----
# RMSE: 0.1132
# RMSE (NPV): 0.1198
# R²: 0.8626
# R² (NPV): 0.8227
# R² (y = x): 0.8674
# R² (y = x) (NPV): 0.8227
# ...

# %%
general_functions.run_dirichlet_model_epistemic("simpler_data.csv", wsig=2, bsig=2)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 4134 seconds.
# ----- Convergence diagnostics -----
# (80, 3, 4000) (3, 4000)
#
# ----- Prediction results using the mean of the predictions -----
# RMSE: 0.1131
# RMSE (NPV): 0.1198
# R²: 0.8628
# R² (NPV): 0.8228
# R² (y = x): 0.8676
# R² (y = x) (NPV): 0.8228
# ----- Plotting epistemic uncertainty (median ± 90% HDPI) -----
