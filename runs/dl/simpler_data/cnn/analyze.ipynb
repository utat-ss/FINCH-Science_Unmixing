# %%
import pickle as pkl
import numpy as np

# %%
cnn_dict = pkl.load(open('cnn_dict.pkl', 'rb'))

# %%
for i in cnn_dict.keys():
    print(f"For {i}, Total R2: {cnn_dict[i]['metrics_total'][0][3]}, param#: {cnn_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in cnn_dict.keys():
    print(f"For {i}, GV R2: {cnn_dict[i]['metrics_total'][0][4]}, param#: {cnn_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in cnn_dict.keys():
    print(f"For {i}, NPV R2: {cnn_dict[i]['metrics_total'][0][5]}, param#: {cnn_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in cnn_dict.keys():
    print(f"For {i}, Soil R2: {cnn_dict[i]['metrics_total'][0][6]}, param#: {cnn_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in cnn_dict.keys():
    print(f"For {i}, RMSE: {np.sqrt(cnn_dict[i]['metrics_total'][0][2])}, param#: {cnn_dict[i]['metrics_total'][0][0]}")
# Out:
# For CNN_8, Total R2: 0.8384947776794434, param#: 11185.0
# For CNN_16, Total R2: 0.8558691143989563, param#: 12089.0
# For CNN_32, Total R2: 0.8682694435119629, param#: 16633.0
# For CNN_64, Total R2: 0.8691044449806213, param#: 33321.0
# For CNN_128, Total R2: 0.8653088212013245, param#: 103721.0
# For CNN_256, Total R2: 0.7739248275756836, param#: 379401.0
# For CNN_512, Total R2: 0.8215606808662415, param#: 1496585.0
#
#
# For CNN_8, GV R2: 0.8470391035079956, param#: 11185.0
# For CNN_16, GV R2: 0.8543119430541992, param#: 12089.0
# For CNN_32, GV R2: 0.8647651672363281, param#: 16633.0
# For CNN_64, GV R2: 0.8772768974304199, param#: 33321.0
# For CNN_128, GV R2: 0.8533414602279663, param#: 103721.0
# For CNN_256, GV R2: 0.8381718397140503, param#: 379401.0
# For CNN_512, GV R2: 0.8410709500312805, param#: 1496585.0
#
#
# For CNN_8, NPV R2: 0.7617353200912476, param#: 11185.0
# For CNN_16, NPV R2: 0.775685727596283, param#: 12089.0
# For CNN_32, NPV R2: 0.8020049333572388, param#: 16633.0
# For CNN_64, NPV R2: 0.794651448726654, param#: 33321.0
# For CNN_128, NPV R2: 0.805095374584198, param#: 103721.0
# For CNN_256, NPV R2: 0.6337568759918213, param#: 379401.0
# For CNN_512, NPV R2: 0.7285876274108887, param#: 1496585.0
#
#
# For CNN_8, Soil R2: 0.9067097902297974, param#: 11185.0
# For CNN_16, Soil R2: 0.9376097321510315, param#: 12089.0
# For CNN_32, Soil R2: 0.9380383491516113, param#: 16633.0
# For CNN_64, Soil R2: 0.9353849291801453, param#: 33321.0
# For CNN_128, Soil R2: 0.9374896883964539, param#: 103721.0
# For CNN_256, Soil R2: 0.8498458862304688, param#: 379401.0
# For CNN_512, Soil R2: 0.8950235843658447, param#: 1496585.0
#
#
# For CNN_8, RMSE: 0.11091565383803495, param#: 11185.0
# For CNN_16, RMSE: 0.10308739868926696, param#: 12089.0
# For CNN_32, RMSE: 0.10094569507346585, param#: 16633.0
# For CNN_64, RMSE: 0.10036854259888325, param#: 33321.0
# For CNN_128, RMSE: 0.102005108738392, param#: 103721.0
# For CNN_256, RMSE: 0.12810202631023362, param#: 379401.0
# For CNN_512, RMSE: 0.11701843861969029, param#: 1496585.0
