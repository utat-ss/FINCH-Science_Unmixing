# %%
import pickle as pkl
import numpy as np

# %%
fno_dict = pkl.load(open('fno_dict.pkl', 'rb'))

# %%
for i in fno_dict.keys():
    print(f"For {i}, Total R2: {fno_dict[i]['metrics_total'][0][3]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, GV R2: {fno_dict[i]['metrics_total'][0][4]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, NPV R2: {fno_dict[i]['metrics_total'][0][5]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, Soil R2: {fno_dict[i]['metrics_total'][0][6]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, RMSE: {np.sqrt(fno_dict[i]['metrics_total'][0][2])}, param#: {fno_dict[i]['metrics_total'][0][0]}")
# Out:
# For FNO_8, Total R2: 0.796008825302124, param#: 116539.0
# For FNO_16, Total R2: 0.8271121978759766, param#: 154019.0
# For FNO_32, Total R2: 0.8512725234031677, param#: 315315.0
# For FNO_64, Total R2: 0.8436067700386047, param#: 1186387.0
# For FNO_128, Total R2: 0.856124222278595, param#: 4657043.0
# For FNO_256, Total R2: 0.8480324149131775, param#: 18652947.0
#
#
# For FNO_8, GV R2: 0.8326817154884338, param#: 116539.0
# For FNO_16, GV R2: 0.8228456974029541, param#: 154019.0
# For FNO_32, GV R2: 0.8553714752197266, param#: 315315.0
# For FNO_64, GV R2: 0.8583931922912598, param#: 1186387.0
# For FNO_128, GV R2: 0.862190842628479, param#: 4657043.0
# For FNO_256, GV R2: 0.8592170476913452, param#: 18652947.0
#
#
# For FNO_8, NPV R2: 0.652381181716919, param#: 116539.0
# For FNO_16, NPV R2: 0.7443453073501587, param#: 154019.0
# For FNO_32, NPV R2: 0.767092764377594, param#: 315315.0
# For FNO_64, NPV R2: 0.7621111869812012, param#: 1186387.0
# For FNO_128, NPV R2: 0.782839834690094, param#: 4657043.0
# For FNO_256, NPV R2: 0.7629807591438293, param#: 18652947.0
#
#
# For FNO_8, Soil R2: 0.9029636979103088, param#: 116539.0
# For FNO_16, Soil R2: 0.9141456484794617, param#: 154019.0
# For FNO_32, Soil R2: 0.9313532710075378, param#: 315315.0
# For FNO_64, Soil R2: 0.9103160500526428, param#: 1186387.0
# For FNO_128, Soil R2: 0.9233419299125671, param#: 4657043.0
# For FNO_256, Soil R2: 0.9218993186950684, param#: 18652947.0
#
#
# For FNO_8, RMSE: 0.12112768143898191, param#: 116539.0
# For FNO_16, RMSE: 0.11307929798591561, param#: 154019.0
# For FNO_32, RMSE: 0.10820879542644785, param#: 315315.0
# For FNO_64, RMSE: 0.11137749179708152, param#: 1186387.0
# For FNO_128, RMSE: 0.10767529246528794, param#: 4657043.0
# For FNO_256, RMSE: 0.10745989386808528, param#: 18652947.0
