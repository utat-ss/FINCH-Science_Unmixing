# %%
import pickle as pkl
import numpy as np

# %%
fno_dict = pkl.load(open('fno_dict.pkl', 'rb'))

# %%
for i in fno_dict.keys():
    print(f"For {i}, Total R2: {fno_dict[i]['metrics_total'][0][3]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, GV R2: {fno_dict[i]['metrics_total'][0][4]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, NPV R2: {fno_dict[i]['metrics_total'][0][5]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, Soil R2: {fno_dict[i]['metrics_total'][0][6]}, param#: {fno_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in fno_dict.keys():
    print(f"For {i}, RMSE: {np.sqrt(fno_dict[i]['metrics_total'][0][2])}, param#: {fno_dict[i]['metrics_total'][0][0]}")
# Out:
# For FNO_8, Total R2: 0.8455621600151062, param#: 116539.0
# For FNO_16, Total R2: 0.8749879002571106, param#: 154019.0
# For FNO_32, Total R2: 0.8709765076637268, param#: 315315.0
# For FNO_64, Total R2: 0.870704174041748, param#: 1186387.0
# For FNO_128, Total R2: 0.8869986534118652, param#: 4657043.0
# For FNO_256, Total R2: 0.8697457313537598, param#: 18652947.0
#
#
# For FNO_8, GV R2: 0.8770469427108765, param#: 116539.0
# For FNO_16, GV R2: 0.8848485350608826, param#: 154019.0
# For FNO_32, GV R2: 0.8910462260246277, param#: 315315.0
# For FNO_64, GV R2: 0.889662504196167, param#: 1186387.0
# For FNO_128, GV R2: 0.8963473439216614, param#: 4657043.0
# For FNO_256, GV R2: 0.8851542472839355, param#: 18652947.0
#
#
# For FNO_8, NPV R2: 0.7738907337188721, param#: 116539.0
# For FNO_16, NPV R2: 0.80646151304245, param#: 154019.0
# For FNO_32, NPV R2: 0.8099410533905029, param#: 315315.0
# For FNO_64, NPV R2: 0.81699138879776, param#: 1186387.0
# ...
