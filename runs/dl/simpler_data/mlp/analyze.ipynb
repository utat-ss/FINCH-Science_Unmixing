# %%
import pickle as pkl
import numpy as np

# %%
mlp_dict = pkl.load(open('mlp_dict.pkl', 'rb'))

# %%
for i in mlp_dict.keys():
    print(f"For {i}, Total R2: {mlp_dict[i]['metrics_total'][0][3]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, GV R2: {mlp_dict[i]['metrics_total'][0][4]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, NPV R2: {mlp_dict[i]['metrics_total'][0][5]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, Soil R2: {mlp_dict[i]['metrics_total'][0][6]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, RMSE: {np.sqrt(mlp_dict[i]['metrics_total'][0][2])}, param#: {mlp_dict[i]['metrics_total'][0][0]}")
# Out:
# For MLP_32, Total R2: 0.814842939376831, param#: 3875.0
# For MLP_64_3layer, Total R2: 0.8526074886322021, param#: 14083.0
# For MLP_128_4layer, Total R2: 0.8715705275535583, param#: 61315.0
# For MLP_256_4layer, Total R2: 0.8643435835838318, param#: 220931.0
# For MLP_512_5layer, Total R2: 0.8593601584434509, param#: 1098755.0
# For MLP_64_1k_5layer, Total R2: 0.8343258500099182, param#: 3294787.0
# For MLP_64_2k_7layer, Total R2: 0.8489572405815125, param#: 25470531.0
#
#
# For MLP_32, GV R2: 0.8568308353424072, param#: 3875.0
# For MLP_64_3layer, GV R2: 0.8815528154373169, param#: 14083.0
# For MLP_128_4layer, GV R2: 0.8755961656570435, param#: 61315.0
# For MLP_256_4layer, GV R2: 0.8738048076629639, param#: 220931.0
# For MLP_512_5layer, GV R2: 0.8587043285369873, param#: 1098755.0
# For MLP_64_1k_5layer, GV R2: 0.8506542444229126, param#: 3294787.0
# For MLP_64_2k_7layer, GV R2: 0.8721415996551514, param#: 25470531.0
#
#
# For MLP_32, NPV R2: 0.6955884099006653, param#: 3875.0
# For MLP_64_3layer, NPV R2: 0.761926531791687, param#: 14083.0
# For MLP_128_4layer, NPV R2: 0.8036912083625793, param#: 61315.0
# For MLP_256_4layer, NPV R2: 0.7890418767929077, param#: 220931.0
# For MLP_512_5layer, NPV R2: 0.7889518141746521, param#: 1098755.0
# For MLP_64_1k_5layer, NPV R2: 0.7468029260635376, param#: 3294787.0
# For MLP_64_2k_7layer, NPV R2: 0.771522581577301, param#: 25470531.0
#
#
# For MLP_32, Soil R2: 0.8921096920967102, param#: 3875.0
# For MLP_64_3layer, Soil R2: 0.9143430590629578, param#: 14083.0
# For MLP_128_4layer, Soil R2: 0.9354240894317627, param#: 61315.0
# For MLP_256_4layer, Soil R2: 0.930184006690979, param#: 220931.0
# For MLP_512_5layer, Soil R2: 0.9304242134094238, param#: 1098755.0
# For MLP_64_1k_5layer, Soil R2: 0.9055203795433044, param#: 3294787.0
# For MLP_64_2k_7layer, Soil R2: 0.9032074213027954, param#: 25470531.0
#
#
# For MLP_32, RMSE: 0.11350535554371174, param#: 3875.0
# For MLP_64_3layer, RMSE: 0.10367912300202818, param#: 14083.0
# For MLP_128_4layer, RMSE: 0.09789765085396385, param#: 61315.0
# For MLP_256_4layer, RMSE: 0.09934153731174802, param#: 220931.0
# For MLP_512_5layer, RMSE: 0.10144028279171073, param#: 1098755.0
# For MLP_64_1k_5layer, RMSE: 0.11131355959994638, param#: 3294787.0
# For MLP_64_2k_7layer, RMSE: 0.10346060766311399, param#: 25470531.0
