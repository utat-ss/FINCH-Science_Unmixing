# %%
import pickle as pkl
import numpy as np

# %%
mlp_dict = pkl.load(open('mlp_dict.pkl', 'rb'))

# %%
for i in mlp_dict.keys():
    print(f"For {i}, Total R2: {mlp_dict[i]['metrics_total'][0][3]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, GV R2: {mlp_dict[i]['metrics_total'][0][4]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, NPV R2: {mlp_dict[i]['metrics_total'][0][5]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, Soil R2: {mlp_dict[i]['metrics_total'][0][6]}, param#: {mlp_dict[i]['metrics_total'][0][0]}")

print("\n")

for i in mlp_dict.keys():
    print(f"For {i}, RMSE: {np.sqrt(mlp_dict[i]['metrics_total'][0][2])}, param#: {mlp_dict[i]['metrics_total'][0][0]}")
# Out:
# For MLP_32, Total R2: 0.8520388603210449, param#: 3875.0
# For MLP_64_3layer, Total R2: 0.8624549508094788, param#: 14083.0
# For MLP_128_4layer, Total R2: 0.8934910297393799, param#: 61315.0
# For MLP_256_4layer, Total R2: 0.8920806050300598, param#: 220931.0
# For MLP_512_5layer, Total R2: 0.8735866546630859, param#: 1098755.0
# For MLP_64_1k_5layer, Total R2: 0.8104147911071777, param#: 3294787.0
# For MLP_64_2k_7layer, Total R2: 0.8312557339668274, param#: 25470531.0
#
#
# For MLP_32, GV R2: 0.8457664251327515, param#: 3875.0
# For MLP_64_3layer, GV R2: 0.8534854054450989, param#: 14083.0
# For MLP_128_4layer, GV R2: 0.8902433514595032, param#: 61315.0
# For MLP_256_4layer, GV R2: 0.8857284784317017, param#: 220931.0
# For MLP_512_5layer, GV R2: 0.8588796854019165, param#: 1098755.0
# For MLP_64_1k_5layer, GV R2: 0.8377116918563843, param#: 3294787.0
# For MLP_64_2k_7layer, GV R2: 0.8534125685691833, param#: 25470531.0
#
#
# For MLP_32, NPV R2: 0.7825720310211182, param#: 3875.0
# ...
