# %%
import general_functions
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/arviz/__init__.py:50: FutureWarning:
# ArviZ is undergoing a major refactor to improve flexibility and extensibility while maintaining a user-friendly interface.
# Some upcoming changes may be backward incompatible.
# For details and migration guidance, visit: https://python.arviz.org/en/latest/user_guide/migration_guide.html
#   warn(

# %%
print('======================== Lab Dataset Results ======================== ')
print(' \n Dirichlet model - aleatoric and epistemic uncertainty')
general_functions.run_dirichlet_model("simpler_data.csv")
# Out:
# Initializing NUTS using jitter+adapt_diag...
# ======================== Lab Dataset Results ========================
#
#  Dirichlet model - aleatoric and epistemic uncertainty
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 2008 seconds.
# ----- Convergence diagnostics -----
# w shape: (80, 3, 4000), b shape: (3, 4000)
# linear shape: (4000, 345, 3), any nan: False, any inf: False
# alpha shape: (4000, 345, 3), min: 0.0036, max: 18.4450
#
# ----- Prediction results using the mean of the predictions -----
# RMSE: 0.1345
# ...

# %%
print(' \n Dirichlet model - epistemic uncertainty')
general_functions.run_dirichlet_model_epistemic("simpler_data.csv")
# Out:
#
#  Dirichlet model - epistemic uncertainty
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1351 seconds.
# ----- Convergence diagnostics -----
# (80, 3, 4000) (3, 4000)
#
# ----- Prediction results using the mean of the predictions -----
# RMSE: 0.1343
# RMSE (NPV): 0.1403
# R²: 0.8053
# R² (NPV): 0.7707
# R² (y = x): 0.8123
# R² (y = x) (NPV): 0.7707
# ----- Plotting epistemic uncertainty (median ± 90% HDPI) -----

# %%
# run models on lab dataset - MVLR
print(' \n MVLR - aleatoric and epistemic uncertainty')
general_functions.run_bayesian_mvlr("simpler_data.csv")
# Out:
#
#  MVLR - aleatoric and epistemic uncertainty
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b, sigma]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymc/step_methods/hmc/quadpotential.py:316: RuntimeWarning: overflow encountered in dot
#   return 0.5 * np.dot(x, v_out)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymc/step_methods/hmc/quadpotential.py:316: RuntimeWarning: overflow encountered in dot
#   return 0.5 * np.dot(x, v_out)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymc/step_methods/hmc/quadpotential.py:316: RuntimeWarning: overflow encountered in dot
#   return 0.5 * np.dot(x, v_out)
# ...

# %%
print(' \n MVLR - epistemic uncertainty')
general_functions.run_bayesian_mvlr_epistemic("simpler_data.csv")
# Out:
#
#  MVLR - epistemic uncertainty
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b, sigma]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 9828 seconds.
# ----- Convergence diagnostics -----
# ----- Prediction results using the mean of the predictions -----
# RMSE: 0.1245
# RMSE (NPV): 0.1355
# R²: 0.8350
# R² (NPV): 0.7860
# R² (y = x): 0.8387
# R² (y = x) (NPV): 0.7860
# ----- Plotting epistemic uncertainty (median ± 90% HDPI) -----

# %%
# run models on atmo dataset - dirichlet model
# run models on lab dataset - dirichlet model
print('======================== Atmo Dataset Results ======================== ')
print(' \n Dirichlet model - aleatoric and epistemic uncertainty')
general_functions.run_dirichlet_model_two_datasets("merged_dataset.csv", "atmo_testing.csv")
# Out:
# ======================== Atmo Dataset Results ========================
#
#  Dirichlet model - aleatoric and epistemic uncertainty
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [w, b]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/rich/live.py:260: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 8397 seconds.
# ----- Convergence diagnostics -----
# w shape: (80, 3, 4000), b shape: (3, 4000)
# linear shape: (4000, 58, 3), any nan: False, any inf: False
# alpha shape: (4000, 58, 3), min: 0.0002, max: 12.0139
#
# ----- Prediction results using the mean of the predictions -----
# RMSE: 0.2435
# ...
